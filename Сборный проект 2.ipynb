# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# Привет, меня зовут Александр Куимов. Я буду ревьюером твоего проекта. Ты можешь обращаться ко мне на "ты"😏 Надеюсь, тебя также не смутит, если я буду обращаться к тебе на "ты", но если это неудобно, обязательно скажи об этом!
#
# Пожалуйста, не удаляй мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Ты также можешь реагировать на мои комментарии своими по шаблону, показанному чуть ниже. Это нужно, чтобы не создавалась путаница😉
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В случае, если решение на отдельном шаге является полностью правильным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> В случае, когда решение на отдельном шаге станет еще лучше, если внести небольшие коррективы.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#  В случае, когда решение на отдельном шаге требует существенной переработки и внесения правок. Напоминаю, что проект не может быть принят с первого раза, если ревью содержит комментарии, рекомендующие доработать шаги.
# </div>
#
#
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> В такой цветовой ячейке я прошу тебя оставлять свои комментарии. Если исправляешь проект на второй итерации и выше, не забывай пожалуйста указывать номер итерации, например, "Комментарий студента v.2".
# </div>
#
# <br/>
#
# Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие и дам тебе возможность самому найти и исправить ее. На реальной работе твой руководитель будет поступать также, и я пытаюсь подготовить тебя именно к работе датасаентистом. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку!🤓

# %% [markdown]
# Привет Александр!
#
# По твоим комментариям исправил, кроме подбора третьего гиперпараметра. Гридсерч имеет хороший замысел, но очень долгий, без третьего параметра на поиск ушло 28 мин. С тремя, после полуторачасов не дождавшись результата остановил. + ко всему юпитер периодически переставал работать. Долго копался с ним, но логику понял. Странно что гридсерча нет в обучении, полезная вещь. Надеюсь что это не столь критично, потому как сегодня(в среду) у меня дедлайн(

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Загрузка-необходимых-библиотек" data-toc-modified-id="Загрузка-необходимых-библиотек-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Загрузка необходимых библиотек</a></span></li><li><span><a href="#Загрузка-и-первичный-осмотр" data-toc-modified-id="Загрузка-и-первичный-осмотр-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Загрузка и первичный осмотр</a></span></li><li><span><a href="#Проверка-правильности" data-toc-modified-id="Проверка-правильности-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Проверка правильности</a></span></li><li><span><a href="#Анализ-пизнаков-не-доступные-в-тестовой-выборке" data-toc-modified-id="Анализ-пизнаков-не-доступные-в-тестовой-выборке-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Анализ пизнаков не доступные в тестовой выборке</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Вывод-по-подготовке-данных" data-toc-modified-id="Вывод-по-подготовке-данных-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Вывод по подготовке данных</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Анализ-изменения-концентрации-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки" data-toc-modified-id="Анализ-изменения-концентрации-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Анализ изменения концентрации металлов (Au, Ag, Pb) на различных этапах очистки</a></span></li><li><span><a href="#Сравнение-распределения-размеров-гранул-сырья-на-обучающей-и-тестовых-выборках" data-toc-modified-id="Сравнение-распределения-размеров-гранул-сырья-на-обучающей-и-тестовых-выборках-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Сравнение распределения размеров гранул сырья на обучающей и тестовых выборках</a></span></li><li><span><a href="#Исследование-суммарных-концентраций-всех-веществ-на-разных-стадиях-очистки" data-toc-modified-id="Исследование-суммарных-концентраций-всех-веществ-на-разных-стадиях-очистки-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Исследование суммарных концентраций всех веществ на разных стадиях очистки</a></span></li><li><span><a href="#Выводы-по-анализу-данных" data-toc-modified-id="Выводы-по-анализу-данных-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Выводы по анализу данных</a></span></li></ul></li><li><span><a href="#Модель" data-toc-modified-id="Модель-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Модель</a></span><ul class="toc-item"><li><span><a href="#Функция-для-вычисления-итоговой-sMAPE." data-toc-modified-id="Функция-для-вычисления-итоговой-sMAPE.-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Функция для вычисления итоговой sMAPE.</a></span></li><li><span><a href="#Обучение-моделей-и-оценка-их-качества-кроссвалидацией" data-toc-modified-id="Обучение-моделей-и-оценка-их-качества-кроссвалидацией-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Обучение моделей и оценка их качества кроссвалидацией</a></span><ul class="toc-item"><li><span><a href="#Решающее-дерево" data-toc-modified-id="Решающее-дерево-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Решающее дерево</a></span></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Случайный лес</a></span></li><li><span><a href="#Линейная-регрессия" data-toc-modified-id="Линейная-регрессия-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Линейная регрессия</a></span></li></ul></li><li><span><a href="#Проверка-лучшей-модели-на-тестовой-выборке" data-toc-modified-id="Проверка-лучшей-модели-на-тестовой-выборке-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Проверка лучшей модели на тестовой выборке</a></span></li><li><span><a href="#Проверка-на-адекватность" data-toc-modified-id="Проверка-на-адекватность-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Проверка на адекватность</a></span></li></ul></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Подготовьте прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Вам нужно:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.
#
# Чтобы выполнить проект, обращайтесь к библиотекам *pandas*, *matplotlib* и *sklearn.* Вам поможет их документация.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Вижу твое добавленное описание проекта. Молодец! Это поможет тебе расставлять акценты в выводах

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Загрузка необходимых библиотек

# %%
import pandas as pd
from sklearn.metrics import mean_absolute_error
import seaborn as sb
import matplotlib.pyplot as plt
from sklearn.metrics import make_scorer
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_val_score
import numpy as np
from sklearn.preprocessing import StandardScaler 
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.dummy import DummyRegressor
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ### Загрузка и первичный осмотр

# %%
data_train = pd.read_csv('/datasets/gold_recovery_train_new.csv')
data_test = pd.read_csv('/datasets/gold_recovery_test_new.csv')
data_full = pd.read_csv('/datasets/gold_recovery_full_new.csv')

# %%
print(data_train.shape)
print()
print(data_test.shape)
print()
print(data_full.shape)
# Out:
# (14149, 87)
#
# (5290, 53)
#
# (19439, 87)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
display(data_train.head())
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# ...

# %%
data_test.head()
# Out:
#                   date  primary_cleaner.input.sulfate  \
# 0  2016-09-01 00:59:59                     210.800909
# 1  2016-09-01 01:59:59                     215.392455
# 2  2016-09-01 02:59:59                     215.259946
# 3  2016-09-01 03:59:59                     215.336236
# 4  2016-09-01 04:59:59                     199.099327
#
#    primary_cleaner.input.depressant  primary_cleaner.input.feed_size  \
# 0                         14.993118                         8.080000
# 1                         14.987471                         8.080000
# 2                         12.884934                         7.786667
# 3                         12.006805                         7.640000
# 4                         10.682530                         7.530000
#
#    primary_cleaner.input.xanthate  primary_cleaner.state.floatbank8_a_air  \
# 0                        1.005021                             1398.981301
# ...

# %% [markdown]
# в тестовой таблице время смещено на секунду, странно

# %%
data_full.head()
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# ...

# %% [markdown]
# Слишком много столбцов, просто так и не взглянешь. Хотя по первому столбцу понятно, что данные вносились каждый час. Посмотрим на общую информацию.

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14149 entries, 0 to 14148
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                14149 non-null  object
#  1   final.output.concentrate_ag                         14148 non-null  float64
#  2   final.output.concentrate_pb                         14148 non-null  float64
#  3   final.output.concentrate_sol                        13938 non-null  float64
#  4   final.output.concentrate_au                         14149 non-null  float64
#  5   final.output.recovery                               14149 non-null  float64
#  6   final.output.tail_ag                                14149 non-null  float64
#  7   final.output.tail_pb                                14049 non-null  float64
# ...

# %%
data_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5290 entries, 0 to 5289
# Data columns (total 53 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   date                                        5290 non-null   object
#  1   primary_cleaner.input.sulfate               5286 non-null   float64
#  2   primary_cleaner.input.depressant            5285 non-null   float64
#  3   primary_cleaner.input.feed_size             5290 non-null   float64
#  4   primary_cleaner.input.xanthate              5286 non-null   float64
#  5   primary_cleaner.state.floatbank8_a_air      5290 non-null   float64
#  6   primary_cleaner.state.floatbank8_a_level    5290 non-null   float64
#  7   primary_cleaner.state.floatbank8_b_air      5290 non-null   float64
#  8   primary_cleaner.state.floatbank8_b_level    5290 non-null   float64
# ...

# %%
data_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19439 entries, 0 to 19438
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                19439 non-null  object
#  1   final.output.concentrate_ag                         19438 non-null  float64
#  2   final.output.concentrate_pb                         19438 non-null  float64
#  3   final.output.concentrate_sol                        19228 non-null  float64
#  4   final.output.concentrate_au                         19439 non-null  float64
#  5   final.output.recovery                               19439 non-null  float64
#  6   final.output.tail_ag                                19438 non-null  float64
#  7   final.output.tail_pb                                19338 non-null  float64
# ...

# %% [markdown]
# Почти все столбцы во всех таблицах имеют тип float, кроме столбца date, он имеет тип object. Надо будет его в дальнейшем перевести в дату.
#
# Посмотрим на количество пропусков и в каких столбцах.

# %%
data_train.isna().sum()
# Out:
# date                                                     0
# final.output.concentrate_ag                              1
# final.output.concentrate_pb                              1
# final.output.concentrate_sol                           211
# final.output.concentrate_au                              0
# final.output.recovery                                    0
# final.output.tail_ag                                     0
# final.output.tail_pb                                   100
# final.output.tail_sol                                    5
# final.output.tail_au                                     0
# primary_cleaner.input.sulfate                           20
# primary_cleaner.input.depressant                        32
# primary_cleaner.input.feed_size                          0
# primary_cleaner.input.xanthate                         100
# primary_cleaner.output.concentrate_ag                    0
# primary_cleaner.output.concentrate_pb                   86
# ...

# %% [markdown]
# Больше всего пропусков в secondary_cleaner.output.tail_sol и в rougher.state.floatbank10_e_air

# %%
data_test.isna().sum()
# Out:
# date                                           0
# primary_cleaner.input.sulfate                  4
# primary_cleaner.input.depressant               5
# primary_cleaner.input.feed_size                0
# primary_cleaner.input.xanthate                 4
# primary_cleaner.state.floatbank8_a_air         0
# primary_cleaner.state.floatbank8_a_level       0
# primary_cleaner.state.floatbank8_b_air         0
# primary_cleaner.state.floatbank8_b_level       0
# primary_cleaner.state.floatbank8_c_air         0
# primary_cleaner.state.floatbank8_c_level       0
# primary_cleaner.state.floatbank8_d_air         0
# primary_cleaner.state.floatbank8_d_level       0
# rougher.input.feed_ag                          0
# rougher.input.feed_pb                          0
# rougher.input.feed_rate                        3
# rougher.input.feed_size                        1
# rougher.input.feed_sol                        21
# rougher.input.feed_au                          0
# ...

# %% [markdown]
# Пропуски тоже есть, но уже считанные единицы.

# %%
data_full.isna().sum()
# Out:
# date                                                     0
# final.output.concentrate_ag                              1
# final.output.concentrate_pb                              1
# final.output.concentrate_sol                           211
# final.output.concentrate_au                              0
# final.output.recovery                                    0
# final.output.tail_ag                                     1
# final.output.tail_pb                                   101
# final.output.tail_sol                                    6
# final.output.tail_au                                     0
# primary_cleaner.input.sulfate                           24
# primary_cleaner.input.depressant                        37
# primary_cleaner.input.feed_size                          0
# primary_cleaner.input.xanthate                         104
# primary_cleaner.output.concentrate_ag                    0
# primary_cleaner.output.concentrate_pb                  116
# ...

# %% [markdown]
# Посмотрим на наличие явных дубликатов

# %%
print(data_train.duplicated().sum())
print(data_test.duplicated().sum())
print(data_full.duplicated().sum())
# Out:
# 0
# 0
# 0

# %% [markdown]
# Явных дубликатов не выявлено
#
# Посмотрим на численные описание, может будет легче для аосприятия.

# %%
data_train.describe().T
# Out:
#                                                       count          mean  \
# final.output.concentrate_ag                         14148.0      5.142034
# final.output.concentrate_pb                         14148.0     10.132960
# final.output.concentrate_sol                        13938.0      9.202849
# final.output.concentrate_au                         14149.0     44.003792
# final.output.recovery                               14149.0     66.518832
# final.output.tail_ag                                14149.0      9.607035
# final.output.tail_pb                                14049.0      2.597298
# final.output.tail_sol                               14144.0     10.512122
# final.output.tail_au                                14149.0      2.918421
# primary_cleaner.input.sulfate                       14129.0    133.320659
# primary_cleaner.input.depressant                    14117.0      8.866996
# primary_cleaner.input.feed_size                     14149.0      7.322310
# ...

# %%
data_test.describe().T
# Out:
#                                              count         mean         std  \
# primary_cleaner.input.sulfate               5286.0   174.839652   43.027080
# primary_cleaner.input.depressant            5285.0     8.683596    3.072050
# primary_cleaner.input.feed_size             5290.0     7.266339    0.610219
# primary_cleaner.input.xanthate              5286.0     1.383803    0.643474
# primary_cleaner.state.floatbank8_a_air      5290.0  1539.494325  116.797884
# primary_cleaner.state.floatbank8_a_level    5290.0  -497.665883   19.952431
# primary_cleaner.state.floatbank8_b_air      5290.0  1545.174232  122.224588
# primary_cleaner.state.floatbank8_b_level    5290.0  -500.273098   32.968307
# primary_cleaner.state.floatbank8_c_air      5290.0  1527.272362  122.538034
# primary_cleaner.state.floatbank8_c_level    5290.0  -498.330680   21.964876
# primary_cleaner.state.floatbank8_d_air      5290.0  1544.844335  124.773081
# ...

# %%
data_full.describe().T
# Out:
#                                                       count          mean  \
# final.output.concentrate_ag                         19438.0      5.168470
# final.output.concentrate_pb                         19438.0      9.978895
# final.output.concentrate_sol                        19228.0      9.501224
# final.output.concentrate_au                         19439.0     44.076513
# final.output.recovery                               19439.0     67.050208
# final.output.tail_ag                                19438.0      9.688589
# final.output.tail_pb                                19338.0      2.705795
# final.output.tail_sol                               19433.0     10.583728
# final.output.tail_au                                19439.0      3.042467
# primary_cleaner.input.sulfate                       19415.0    144.624774
# primary_cleaner.input.depressant                    19402.0      8.817039
# primary_cleaner.input.feed_size                     19439.0      7.307078
# ...

# %% [markdown]
# Численные описания можно визуально взглядом охватить о чем идет речь, но всё равно слишком много информации.
#
# На данный момент понятно, что:
#
#     - train и full имеют по 87 столбцов, test только 53.
#
#     - данные имеют тип float, кроме столбца даты(object).
#
#     - данные вносились ежечасно.
#
#     - во всех таблицах присутствуют пропуски в данных
#
#     - явных дубликатов нет.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# С данными познакомились, проведен первичный аналитический осмотр!) Полученная информация поможет нам в дальнейшем с предобработкой данных

# %% [markdown]
# ### Проверка правильности

# %%
C = data_train['rougher.output.concentrate_au'] # доля золота в концентрате после флотации/очистки;
F = data_train['rougher.input.feed_au']   #  доля золота в сырье/концентрате до флотации/очистки;
T = data_train['rougher.output.tail_au']  #  доля золота в отвальных хвостах после флотации/очистки


data_train['recovery'] = (C * (F - T)) / (F * (C - T)) * 100 # Создаю новый столбец с расчитанными 
                                                            # данными эффективности обогащения

mean_absolute_error(data_train['rougher.output.recovery'], data_train['recovery']) # MAE
# Out:
# 9.73512347450521e-15

# %% [markdown]
# Значение средней ошибки очень мало, и соответственно можно сказать, что столбец rougher.output.recovery заполнен верно.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Твое расссчитанное значение `MAE` верно)

# %% [markdown]
# Думаю, после проверки данный столбец в дальнейшем не пригодится, удалим его.

# %%
data_train.drop('recovery', axis=1, inplace=True)

# %% [markdown]
# ### Анализ пизнаков не доступные в тестовой выборке

# %% [markdown]
# Посмотрим, каких признаков не хватает в тесовой выборке. Сравним названия столбцов тренеровочной таблицы и тестовой, отсутствующие будут попадать в список.

# %%
missing_columns = []
for i in data_train.columns:
    if i not in data_test.columns:
        missing_columns.append(i)

print(len(missing_columns))        
missing_columns
# Out:
# 34
# ['final.output.concentrate_ag',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.concentrate_au',
#  'final.output.recovery',
#  'final.output.tail_ag',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'final.output.tail_au',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'primary_cleaner.output.tail_au',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
#  'rougher.output.concentrate_au',
#  'rougher.output.recovery',
# ...

# %% [markdown]
# Если брать из описания задачи, то "расшифровка" данных столбцов:
#
#     финальные характеристики, параметры продукта (в концентрате и в отвальных хвостах, а также эффективность обогащения)
#
#     первичная очистка, параметры продукта
#
#     флотация, расчётные характеристики
#
#     флотация, параметры продукта
#
#     вторичная очистка, параметры продукта.
#
#
# Все эти столбцы характеризуют концентраты, получаемы на каждом этапе техпроцесса, которые не известны при начале запуска процесса обогащения.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# В тестовой выборке недоступны некоторые расчетные (calculation) и выходные (output) характеристики процесса, ведь их невозможно получить либо замерить во время выполнения технологического процесса

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# Предобработку начну со смены типа в столбцах даты.

# %%
data_train['date'] = pd.to_datetime(data_train['date'], format='%Y-%m-%dT%H:%M:%S')
data_test['date'] = pd.to_datetime(data_test['date'], format='%Y-%m-%dT%H:%M:%S')
data_full['date'] = pd.to_datetime(data_full['date'], format='%Y-%m-%dT%H:%M:%S')
print(data_train.date.dtypes)
print(data_test.date.dtypes)
print(data_full.date.dtypes)
# Out:
# datetime64[ns]
# datetime64[ns]
# datetime64[ns]

# %% [markdown]
# Округлим варемя в тестовой таблицы до часа.

# %%
data_test['date'] = data_test['date'].dt.round('60 min')
data_test['date'].head()
# Out:
# 0   2016-09-01 01:00:00
# 1   2016-09-01 02:00:00
# 2   2016-09-01 03:00:00
# 3   2016-09-01 04:00:00
# 4   2016-09-01 05:00:00
# Name: date, dtype: datetime64[ns]

# %% [markdown]
# Добавим в data_test недостающие целевые признаки, индексироваться будут по времени. Остальные признаки, которые отсутствуют в data_test удалим из data_train

# %%
a = data_full[['date', 'rougher.output.recovery', 'final.output.recovery']]
data_test = data_test.join(a.set_index('date'), on = 'date')
data_test.shape
# Out:
# (5290, 55)

# %%
data_test.isna().sum()
# Out:
# date                                           0
# primary_cleaner.input.sulfate                  4
# primary_cleaner.input.depressant               5
# primary_cleaner.input.feed_size                0
# primary_cleaner.input.xanthate                 4
# primary_cleaner.state.floatbank8_a_air         0
# primary_cleaner.state.floatbank8_a_level       0
# primary_cleaner.state.floatbank8_b_air         0
# primary_cleaner.state.floatbank8_b_level       0
# primary_cleaner.state.floatbank8_c_air         0
# primary_cleaner.state.floatbank8_c_level       0
# primary_cleaner.state.floatbank8_d_air         0
# primary_cleaner.state.floatbank8_d_level       0
# rougher.input.feed_ag                          0
# rougher.input.feed_pb                          0
# rougher.input.feed_rate                        3
# rougher.input.feed_size                        1
# rougher.input.feed_sol                        21
# rougher.input.feed_au                          0
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Вытягивание целевых признаков в тестовую выборку правильное) Привязка к дате - верное решение

# %%
for i in data_train.columns:
    if i not in data_test.columns:
        data_train = data_train.drop([i], axis=1)
print(data_train.shape)
print(data_test.shape)
# Out:
# (14149, 55)
# (5290, 55)

# %% [markdown]
# А теперь заполним пропуски методом ffill, заполняя пропуски в столбцах предыдущим значением по столбцу.

# %%
data_train = data_train.ffill(axis=0)
data_train.isna().sum().sum()
# Out:
# 0

# %%
data_test = data_test.ffill(axis=0)
data_full = data_full.ffill(axis=0)
print(data_test.isna().sum().sum())
print(data_full.isna().sum().sum())
# Out:
# 0
# 0

# %%
data_test.isna().sum()
# Out:
# date                                          0
# primary_cleaner.input.sulfate                 0
# primary_cleaner.input.depressant              0
# primary_cleaner.input.feed_size               0
# primary_cleaner.input.xanthate                0
# primary_cleaner.state.floatbank8_a_air        0
# primary_cleaner.state.floatbank8_a_level      0
# primary_cleaner.state.floatbank8_b_air        0
# primary_cleaner.state.floatbank8_b_level      0
# primary_cleaner.state.floatbank8_c_air        0
# primary_cleaner.state.floatbank8_c_level      0
# primary_cleaner.state.floatbank8_d_air        0
# primary_cleaner.state.floatbank8_d_level      0
# rougher.input.feed_ag                         0
# rougher.input.feed_pb                         0
# rougher.input.feed_rate                       0
# rougher.input.feed_size                       0
# rougher.input.feed_sol                        0
# rougher.input.feed_au                         0
# rougher.input.floatbank10_sulfate             0
# ...

# %% [markdown]
# ### Вывод по подготовке данных

# %% [markdown]
# При подготовке данных было сделано:
#
#     - осмотр трех таблиц: data_train(14149 строк, 87 столбцов); data_test (5290 строк, 53 столбца); data_full(19439 строк, 87 столбца).
#
#     - проведен поиск явных дубликатов
#
#     - проведена проверка правильности заполнения столбца rougher.output.recovery. Столбец заполнен верно.
#
#     - проведен анализ пизнаков не доступные в тестовой выборке. Все эти отсутствующие столбцы характеризуют концентраты, получаемы на каждом этапе техпроцесса, которые не известны при начале запуска процесса обогащения.
#
#     - скорректировано время в столбце date  таблицы data_test. В data_test добавлены столбцы rougher.output.recovery', 'final.output.recovery', а из data_train убраны столбцы, которых нет в тестовой таблице.
#
#     - заполнены пропуски методом ffill.

# %% [markdown]
# <div class="alert  alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Верно!👍:\
# </b> Верное решение по обработке пропусков, в признаках их не много. Все наблюдения представляют собой последовательные измерения, заполнить пропуски можно методами `pandas`: `ffill`/ `bfill`/ `interpolate` , это вполне уместно.\
# Хочу посоветовать тебе статью, которая рассматривает разные способы обработки пропусков, выделяет их плюсы и минусы, думаю, тебе может быть интересно: https://loginom.ru/blog/missing

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ###  Анализ изменения концентрации металлов (Au, Ag, Pb) на различных этапах очистки

# %% [markdown]
# Напишу функцию для построения диаграммы размаха концентрации металлов на различных этапах очистки

# %%
def boxplot (metall, title):
    concentrate = data_full[[f'rougher.input.feed_{metall}',
                             f'rougher.output.concentrate_{metall}',
                             f'primary_cleaner.output.concentrate_{metall}', 
                             f'final.output.concentrate_{metall}',]].stack().reset_index()
    concentrate.columns = ['date', 'stage', 'concentrate']
    concentrate.loc[concentrate.stage == f'rougher.output.concentrate_{metall}', 'stage'] = 'флотация'
    concentrate.loc[concentrate.stage == f'primary_cleaner.output.concentrate_{metall}', 'stage'] = 'первичная очистка'
    concentrate.loc[concentrate.stage == f'final.output.concentrate_{metall}', 'stage'] = 'вторичная очистка'
    concentrate.loc[concentrate.stage == f'rougher.input.feed_{metall}', 'stage'] = 'исходный материал до обработок'
    
    plt.figure(figsize=(15,10))
    sb.set(style='whitegrid')
    ax = sb.boxplot(x = 'stage', y='concentrate', data=concentrate, color='red')
    plt.title(title, fontsize=15, weight='bold')
    plt.xlabel('Этапы очистки сырья', fontsize=15)
    plt.ylabel('Концентрация металла', fontsize=10)

# %%
boxplot(metall="au", title='Диаграмма размаха концентрации золота на различных этапах очистки')

# %%
boxplot(metall="ag", title='Диаграмма размаха концентрации серебра на различных этапах очистки')

# %%
boxplot(metall="pb", title='Диаграмма размаха концентрации свинца на различных этапах очистки')

# %% [markdown]
# Как видно на диаграммах размаха, концентрация золота, серебра и свинца меняется после каждого этапа очистки:
#
#     у золота она растёт, медиана увеличивается с 20 после флотации и до 45 после вторичной очистки
#
#     у серебра она падает, с 13 до 5.
#
#     у свинца с флотации увеличивается с 8 до 10 после первичной очистки и держится около того же уровня после вторичной очистки.

# %% [markdown]
#  <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# </b> Мне интересно было изучить твои графики, практичный и красочный графический анализ. Тут еще ожидается показать на существующих графиках и исходное сырье (rougher.input.feed_..). Добавь, пожалуйста

# %% [markdown]
# Добавил

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %% [markdown]
# ### Сравнение распределения размеров гранул сырья на обучающей и тестовых выборках

# %% [markdown]
# Построю гистограмму распределения размеров гранул сырья в обучающей и тестовой выборке

# %%
a = pd.concat(axis=0, ignore_index=True,
                  objs=[pd.DataFrame.from_dict({'value': data_test['rougher.input.feed_size'], 'Выборка': 'test'}),
                        pd.DataFrame.from_dict({'value': data_train['rougher.input.feed_size'], 'Выборка': 'train'})])
plt.figure(figsize=(15,8))
sb.set(style='darkgrid')
sb.kdeplot(data=a, x="value", hue="Выборка")
plt.title('Распределение размеров гранул сырья на флотации', fontsize=14, weight='bold');
plt.xlabel('Размеры гранул', fontsize=14);
plt.ylabel('Количество', fontsize=14);

# %%
a = pd.concat(axis=0, ignore_index=True,
                  objs=[pd.DataFrame.from_dict({'value': data_test['primary_cleaner.input.feed_size'], 'Выборка': 'test'}),
                        pd.DataFrame.from_dict({'value': data_train['primary_cleaner.input.feed_size'], 'Выборка': 'train'})])
plt.figure(figsize=(15,8))
sb.set(style='darkgrid')
sb.kdeplot(data=a, x="value", hue="Выборка")
plt.title('Распределение размеров гранул сырья на первичной очистке', fontsize=14, weight='bold');
plt.xlabel('Размеры гранул', fontsize=14);
plt.ylabel('Количество', fontsize=14);

# %% [markdown]
# Гистограммы размеров гранул на этапе флотации отличаются, а вот подающиеся на первичную очистку после флотации уже схожи. Скорее всего выборки подходят для оценки

# %% [markdown]
#  <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# Распределения примерно одинаковы. Для сравнения распределений выборок с разным размером лучше использовать графики плотности или kde вместо гистограмм частотности (по оси У доля относительно датасета вместо абсолютного количества). Наличие либо отсутствие разницы будет более очевидным.  Рекомендую тебе нормализовать гистограммы, например используя метод `sns.kdeplot`

# %% [markdown]
# Испоьзовал sb.kdeplot

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %% [markdown]
# ### Исследование суммарных концентраций всех веществ на разных стадиях очистки

# %% [markdown]
# Добавим новые соответствующие столбцы в общую таблицу, где будут указываться суммарная концентрация по стадиям очистки
#
#     rougher.input.feed_total - суммарная концентрация веществ в сырье до флотации
#
#     rougher.output.concentrate_total - суммарная концентрация после флотации
#
#     primary_cleaner.output.concentrate_total - суммарная концентраця после первичной очистки
#
#     final.output.concentrate_total - суммарная концентрация после вторичной очистки

# %%
data_full['rougher.input.feed_total'] = data_full['rougher.input.feed_au'] + \
                                        data_full['rougher.input.feed_ag'] + \
                                        data_full['rougher.input.feed_pb'] + \
                                        data_full['rougher.input.feed_sol']

data_full['rougher.output.concentrate_total'] = data_full['rougher.output.concentrate_au'] +\
                                                data_full['rougher.output.concentrate_ag'] + \
                                                data_full['rougher.output.concentrate_pb'] + \
                                                data_full['rougher.output.concentrate_sol']

data_full['primary_cleaner.output.concentrate_total'] = data_full['primary_cleaner.output.concentrate_au'] + \
                                                        data_full['primary_cleaner.output.concentrate_ag'] + \
                                                        data_full['primary_cleaner.output.concentrate_pb'] + \
                                                        data_full['primary_cleaner.output.concentrate_sol']

data_full['final.output.concentrate_total'] = data_full['final.output.concentrate_au'] + \
                                              data_full['final.output.concentrate_ag'] + \
                                              data_full['final.output.concentrate_pb'] + \
                                              data_full['final.output.concentrate_sol']

# %%
a = pd.concat(axis=0, ignore_index=True,
              objs=[pd.DataFrame.from_dict({'value': data_full['rougher.input.feed_total'], 'Этап': 'Концентрация в сырье'}),
                    pd.DataFrame.from_dict({'value': data_full['rougher.output.concentrate_total'],
                                            'Этап': 'Концентрация после флотации'}),
                    pd.DataFrame.from_dict({'value': data_full['primary_cleaner.output.concentrate_total'],
                                            'Этап': 'Концентрация после первичной очистки'}),
                    pd.DataFrame.from_dict({'value': data_full['final.output.concentrate_total'],
                                            'Этап': 'Концентрация после вторичной очистки'})])


plt.figure(figsize=(15,8))
sb.set(style='darkgrid')
sb.histplot(data=a, x="value", hue="Этап", kde=True)
plt.title('Распределение суммарной концентрации всех веществ на разных стадиях', fontsize=14, weight='bold');
plt.xlabel('Суммарная концентрация', fontsize=14);
plt.ylabel('Количество', fontsize=14);

# %% [markdown]
# По графикам видно, что на каждом этапе очистки присутствует нулевая суммарная концентрация всех веществ, чего в реальности не может быть. Исключим такие случаи из выборок

# %%
delet = data_full[(data_full['rougher.input.feed_total'] == 0) | (data_full['rougher.output.concentrate_total'] == 0) |
            (data_full['primary_cleaner.output.concentrate_total'] == 0) | (data_full['final.output.concentrate_total'] == 0)]

data_train = data_train.query('index not in @delet.index')
data_test = data_test.query('index not in@delet.index')
print(data_train.shape)
print(data_test.shape)
# Out:
# (13727, 55)
# (5157, 55)

# %% [markdown]
# ### Выводы по анализу данных

# %% [markdown]
# В ходе анализа данных был сделан:
#
#     - анализ изменения концентрации металлов на различных этапах очистки, где выявлено:
#
#         у золота она растёт, медиана увеличивается с 20 после флотации и до 45 после вторичной очистки
#
#         у серебра она падает, с 13 до 5.
#
#         у свинца с флотации увеличивается с 8 до 10 после первичной очистки и держится около того же уровня после вторичной очистки.
#
#      - сравнение распределения размеров гранул сырья на тестовой и обучающей выборках. Гистограммы размеров гранул на этапе флотации отличаются, а вот подающиеся на первичную очистку после флотации уже схожи. Скорее всего выборки подходят для оценки
#
#      - исследование суммарных концентраций всех веществ на всех стадиях очистки, где были выявлены записи с нулевыми значениями и в последствии удалины из тренеровочных и тестовых выборок.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
# Замечательно, суммарную концентрацию всех веществ на разных стадиях исследовали и нашли аномалии.
#
# Ведь отдельно по каждому веществу они могут быть (не всегда же есть крупицы золота в руде), а вот суммарно - вряд ли (в руде хоть какие-то элементы, но будут). А если мы имеем ноль, значит большая вероятность неточности в измерениях.
#
# Обучающую выборку нужно очистить от таких аномалий

# %% [markdown]
# ## Модель

# %% [markdown]
# ### Функция для вычисления итоговой sMAPE.

# %% [markdown]
# Напишу функции для вычисления sMAPE и итоговой sMAPE

# %%
def smape(target, predictions):
    return np.mean(abs(target - predictions) / ((abs(target) + abs(predictions)) / 2))*100



def smape_fin(rough, final):
    return 0.25 * rough + 0.75 * final

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Функция правильная)

# %% [markdown]
# ### Обучение моделей и оценка их качества кроссвалидацией

# %% [markdown]
# Разделим обучающую и тестовые выборки на признаки и целевые признаки

# %%
def get_cv_scores(model, features, target, cv=5):
    my_scorer = make_scorer(smape)
    scores = cross_val_score(model, features, target, cv=5, scoring=my_scorer)
    
    return scores.mean()

# %% [markdown]
# Используя все столбцы, модель обучаться категорически отказывается. Поэтому избавимся от "лишних" столбцов, посмотрим какие столбцы коррелируются с целевыми признаками. Начну с формирования признаков для предсказания эффективности обогащения после первого этапа.

# %%
rougher = [column for column in data_train.columns if ('rougher' in column)]
rougher
# Out:
# ['rougher.input.feed_ag',
#  'rougher.input.feed_pb',
#  'rougher.input.feed_rate',
#  'rougher.input.feed_size',
#  'rougher.input.feed_sol',
#  'rougher.input.feed_au',
#  'rougher.input.floatbank10_sulfate',
#  'rougher.input.floatbank10_xanthate',
#  'rougher.input.floatbank11_sulfate',
#  'rougher.input.floatbank11_xanthate',
#  'rougher.output.recovery',
#  'rougher.state.floatbank10_a_air',
#  'rougher.state.floatbank10_a_level',
#  'rougher.state.floatbank10_b_air',
#  'rougher.state.floatbank10_b_level',
#  'rougher.state.floatbank10_c_air',
#  'rougher.state.floatbank10_c_level',
#  'rougher.state.floatbank10_d_air',
#  'rougher.state.floatbank10_d_level',
#  'rougher.state.floatbank10_e_air',
#  'rougher.state.floatbank10_e_level',
#  'rougher.state.floatbank10_f_air',
#  'rougher.state.floatbank10_f_level']

# %%
plt.figure(figsize=(15,15))
sb.heatmap(data_train[rougher].corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Корреляция с остальными признаками крайне слабая, поэтому оставим те, у которых она больше 0,1.

# %%
rougher_col = []
for i in rougher:
    if abs(data_train[i].corr(data_train['rougher.output.recovery'])) > 0.1:
        rougher_col.append(i)
        
rougher_col
# Out:
# ['rougher.input.feed_ag',
#  'rougher.input.feed_pb',
#  'rougher.input.feed_sol',
#  'rougher.input.feed_au',
#  'rougher.input.floatbank10_xanthate',
#  'rougher.input.floatbank11_xanthate',
#  'rougher.output.recovery',
#  'rougher.state.floatbank10_a_air',
#  'rougher.state.floatbank10_a_level']

# %% [markdown]
# Аналогично поступим и для final.output.recovery. Посмотрим на корреляцию с остальными столбцами.

# %%
plt.figure(figsize=(20,20))
sb.heatmap(data_train.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Создам список столбцов для проверки корреляции, но перед этим необходимо избавится от столбца date, потому как он ни на что не влияет и его тип не подходит для просмотра корреляции.

# %%
a = data_train.drop(['date'], axis=1)
columns = a.columns
columns
# Out:
# Index(['final.output.recovery', 'primary_cleaner.input.sulfate',
#        'primary_cleaner.input.depressant', 'primary_cleaner.input.feed_size',
#        'primary_cleaner.input.xanthate',
#        'primary_cleaner.state.floatbank8_a_air',
#        'primary_cleaner.state.floatbank8_a_level',
#        'primary_cleaner.state.floatbank8_b_air',
#        'primary_cleaner.state.floatbank8_b_level',
#        'primary_cleaner.state.floatbank8_c_air',
#        'primary_cleaner.state.floatbank8_c_level',
#        'primary_cleaner.state.floatbank8_d_air',
#        'primary_cleaner.state.floatbank8_d_level', 'rougher.input.feed_ag',
#        'rougher.input.feed_pb', 'rougher.input.feed_rate',
#        'rougher.input.feed_size', 'rougher.input.feed_sol',
#        'rougher.input.feed_au', 'rougher.input.floatbank10_sulfate',
#        'rougher.input.floatbank10_xanthate',
#        'rougher.input.floatbank11_sulfate',
#        'rougher.input.floatbank11_xanthate', 'rougher.output.recovery',
# ...

# %%
final_col = []
for i in columns:
    if abs(data_train[i].corr(data_train['final.output.recovery'])) > 0.1:
        final_col.append(i)
final_col
# Out:
# ['final.output.recovery',
#  'primary_cleaner.input.sulfate',
#  'primary_cleaner.input.depressant',
#  'primary_cleaner.input.xanthate',
#  'primary_cleaner.state.floatbank8_a_air',
#  'primary_cleaner.state.floatbank8_b_air',
#  'primary_cleaner.state.floatbank8_c_air',
#  'rougher.input.feed_ag',
#  'rougher.input.feed_pb',
#  'rougher.input.feed_rate',
#  'rougher.input.feed_sol',
#  'rougher.input.feed_au',
#  'rougher.input.floatbank10_xanthate',
#  'rougher.input.floatbank11_xanthate',
#  'rougher.output.recovery',
#  'rougher.state.floatbank10_a_air',
#  'rougher.state.floatbank10_b_air',
#  'rougher.state.floatbank10_c_air',
#  'rougher.state.floatbank10_d_air',
#  'rougher.state.floatbank10_e_air',
#  'secondary_cleaner.state.floatbank2_a_air',
#  'secondary_cleaner.state.floatbank2_b_air',
#  'secondary_cleaner.state.floatbank3_a_air',
#  'secondary_cleaner.state.floatbank4_a_air',
#  'secondary_cleaner.state.floatbank4_b_air',
# ...

# %%
features_train_rougher = data_train[rougher_col].drop(['rougher.output.recovery'], axis=1)
features_train_final = data_train[final_col].drop(['rougher.output.recovery', 'final.output.recovery'], axis=1)
target_train_rougher = data_train['rougher.output.recovery']
target_train_final = data_train['final.output.recovery']

features_test_rougher = data_test[rougher_col].drop(['rougher.output.recovery'], axis=1)
features_test_final = data_test[final_col].drop(['rougher.output.recovery', 'final.output.recovery'], axis=1)
target_test_rougher = data_test['rougher.output.recovery']
target_test_final = data_test['final.output.recovery']

# %% [markdown]
# Промасштабируем

# %%
scaler_rougher = StandardScaler()
scaler_final = StandardScaler()
scaler_rougher = scaler_rougher.fit(features_train_rougher)
scaler_final = scaler_final.fit(features_train_final)

features_train_rougher = scaler_rougher.transform(features_train_rougher)
features_train_final = scaler_final.transform(features_train_final)
features_test_rougher = scaler_rougher.transform(features_test_rougher)
features_test_final = scaler_final.transform(features_test_final)

# %% [markdown]
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# Чтобы не было утечки в тестовую выборку обучать `StandardScaler` следует на тренировочной выборке, а потом метод `transform` уже применять ко всем выборкам. Исправь пожалуйста.
#  </div>

# %% [markdown]
# Исправил

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %% [markdown]
# #### Решающее дерево

# %%
rnd_state = 12345
best_smape_end = 100
best_depth = 0
for depth in range(1, 15):
    model_1 = DecisionTreeRegressor(max_depth = depth, random_state=rnd_state)
    model_2 = DecisionTreeRegressor(max_depth = depth, random_state=rnd_state)
    
    rougher_smape = get_cv_scores(model_1, features_train_rougher, target_train_rougher)
    final_smape = get_cv_scores(model_2, features_train_final, target_train_final)
    
    smape_end = smape_fin(rougher_smape, final_smape)
    
    if smape_end < best_smape_end:
        best_depth = depth
        best_smape_end = smape_end
      
print('Глубина дерева:', best_depth)
print('Лучший показатель sMAPE', best_smape_end)
# Out:
# Глубина дерева: 2
# Лучший показатель sMAPE 10.779807481931469

# %% [markdown]
# #### Случайный лес

# %%
best_smape_end = 100
best_depth = 0
for depth in range(1, 16):
    model_1 = RandomForestRegressor( max_depth = depth, n_estimators=20, random_state=rnd_state)
    model_2 = RandomForestRegressor(max_depth = depth, n_estimators=20, random_state=rnd_state)
    
    rougher_smape = get_cv_scores(model_1, features_train_rougher, target_train_rougher)
    final_smape = get_cv_scores(model_2, features_train_final, target_train_final) 
    
    smape_end = smape_fin(rougher_smape, final_smape)
    
    if smape_end < best_smape_end:
        best_depth = depth
        best_smape_end = smape_end

print('Глубина дерева:', best_depth)
print('Лучший показатель sMAPE', best_smape_end)
# Out:
# Глубина дерева: 4
# Лучший показатель sMAPE 10.159540187735848

# %%
best_smape_rougher = 100
best_depth = 0
for depth in range(1, 16):
    model_1 = RandomForestRegressor( max_depth = depth, n_estimators=20, random_state=rnd_state)
    
    
    rougher_smape = get_cv_scores(model_1, features_train_rougher, target_train_rougher)
    #final_smape = get_cv_scores(model_2, features_train_final, target_train_final) 
    
    #smape_end = smape_fin(rougher_smape, final_smape)
    
    if rougher_smape < best_smape_rougher:
        best_depth = depth
        best_smape_end = smape_end

print('Глубина дерева:', best_depth)
print('Лучший показатель sMAPE', best_smape_rougher)

# %%
best_smape_end = 100
best_est = 0
for est in range(1, 50):
    model_1 = RandomForestRegressor( max_depth = 4, n_estimators=est, random_state=rnd_state)
    model_2 = RandomForestRegressor(max_depth = 4, n_estimators=est, random_state=rnd_state)
    
    rougher_smape = get_cv_scores(model_1, features_train_rougher, target_train_rougher)
    final_smape = get_cv_scores(model_2, features_train_final, target_train_final) 
    
    smape_end = smape_fin(rougher_smape, final_smape)
    
    if smape_end < best_smape_end:
        best_est = est
        best_smape_end = smape_end

print('Количество деревьев:', best_est)
print('Лучший показатель sMAPE', best_smape_end)
# Out:
# Количество деревьев: 12
# Лучший показатель sMAPE 10.123288892701762

# %% [markdown]
# #### Линейная регрессия

# %%
model_1 = LinearRegression()
model_2 = LinearRegression()

rougher_smape = get_cv_scores(model_1, features_train_rougher, target_train_rougher)
final_smape = get_cv_scores(model_2, features_train_final, target_train_final) 
smape_end = smape_fin(rougher_smape, final_smape)

print('Лучший показатель sMAPE', smape_end)
# Out:
# Лучший показатель sMAPE 10.641099711420376

# %% [markdown]
# Лучший результат показала модель случайного леса sMAPE 10.123, с глубиной 4 и количеством деревьев 12.
#
# Посмотрим, что она покажет на тестовой выборке

# %% [markdown]
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# Следует использовать больше одного набора гиперпараметров хотя бы для одной модели, к примеру, перебирать как `max_depth`, так и `min_sample_leaf`. Напомню, что эти наборы следует еще и перебирать (с гридсерчем или вручную с циклами). Исправь, пожалуйста

# %% [markdown]
# Использовал гридсерч на модели случайного леса. min_samples_leaf уже не применял, потому как прождал безуспешно больше часа, но логика ясна.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %%
# %%time
scorer = make_scorer(smape, greater_is_better=False)
grid_rougher = GridSearchCV(estimator=RandomForestRegressor(random_state=rnd_state), param_grid = {'max_depth': range(1, 15), 
                                                                    'n_estimators': range(1, 20)},
                                                                    #'min_samples_leaf':range(1,5)}, 
                   cv = 5, scoring=scorer)
grid_rougher.fit(features_train_rougher, target_train_rougher)

grid_final = GridSearchCV(estimator=RandomForestRegressor(random_state=rnd_state), param_grid = {'max_depth': range(1, 15), 
                                                                    'n_estimators': range(1, 20)},
                                                                    #'min_samples_leaf':range(1,5)}, 
                   cv = 5, scoring=scorer)
grid_final.fit(features_train_final, target_train_final)



print('Лучшие прараметры для rougher:', grid_rougher.best_params_)
print('Лучшие параметры для final:', grid_final.best_params_)
# Out:
# Лучшие прараметры для rougher: {'max_depth': 7, 'n_estimators': 11}
# Лучшие параметры для final: {'max_depth': 4, 'n_estimators': 6}
# CPU times: user 28min 22s, sys: 2.65 s, total: 28min 24s
# Wall time: 28min 25s

# %% [markdown]
# ### Проверка лучшей модели на тестовой выборке

# %%
model_rougher = RandomForestRegressor(max_depth = 7, n_estimators=11, random_state=rnd_state)
model_final = RandomForestRegressor(max_depth = 4, n_estimators=6, random_state=rnd_state)

model_rougher.fit(features_train_rougher, target_train_rougher)
model_final.fit(features_train_final, target_train_final)

prediction_rougher = model_rougher.predict(features_test_rougher)
prediction_final = model_final.predict(features_test_final)

rougher_smape = smape(target_test_rougher, prediction_rougher)
final_smape = smape(target_test_final, prediction_final)
smape_end = smape_fin(rougher_smape, final_smape)



print('Показатель smape', smape_end)
# Out:
# Показатель smape 9.494709473589973

# %% [markdown]
# На тестовой выборке результат получился даже лучше, чем на обучающей.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# Кросс-валидацию некорректно применять к тестовой выборке, поскольку валидация и тестирование - это два отдельных этапа. Для кросс-валидации мы используем тренировочный набор, несколько раз разбиваем его на подвыборки и смотрим, насколько модель устойчива к смене данных, насколько в среднем она результативна. Затем с этой точки зрения выбирается самая учтойчивая и самая результативная модель - победитель. На этом этап кросс-валидации заканчивается, и мы переходим к тестированию победителя. Мы обучаем его на всей тренировочной выборке (без разбивки на подтренировочные и валидационные) и проверяем, насколько хорошие предсказания она дает на тестовой выборке. Это важно нам для того, чтобы понять, действительно ли выбранная модель будет так же хорошо работать на новых незнакомых ей данных, которые ни разу не использовались ни при тренировке, ни при валидации, и не словили ли мы переобучение.
#
# Следует лишь обучить модель на обучающей выборке и сделать предсказание методом `predict` на тестовой выборке и рассчитать итоговое sMAPE.

# %% [markdown]
# Исправил
#
# Сам в шоке от подобной глупой ошибки)
#
# Писал на "автомате".

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %% [markdown]
# ### Проверка на адекватность

# %% [markdown]
# Проверять на адекватность буду с помощью DummyRegressor.

# %%
model_1 = DummyRegressor(strategy='mean')
model_2 = DummyRegressor(strategy='mean')
    
rougher_smape = get_cv_scores(model_1, features_train_rougher, target_train_rougher)
final_smape = get_cv_scores(model_2, features_train_final, target_train_final) 
    
smape_end = smape_fin(rougher_smape, final_smape)
print('Показатель sMAPE', smape_end)
# Out:
# Показатель sMAPE 11.220128808827205

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Молодец, что проводишь сравнение своей модели с константной дамми моделью. В каждом проекте при оценке качества модели, имеет смысл проводить такую проверку на адекватность

# %% [markdown]
# Модель случайного леса действительно оказалась рабочей, так как качество sMAPE у нее действительно лучше чем у DummyRegressor.

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
#
# <h2> Итоговый комментарий ревьюера <a class="tocSkip"> </h2>
#
#
# У меня сложилось хорошее общее впечатление о проекте, тебе удалось неплохо справиться с таким объемным и сложным проектом. Молодец! Подготовлены данные для анализа, изучен каждый параметр. Все красиво визуализировано, построено несколько моделей регрессии и оценено их качество. Осмысленная аналитика и дельная модельная работа - многое удалось как надо)
#
# Отмечу отдельные положительные моменты проекта🙂:
#
# - в ходе проекта встречались функции, помогающие избавиться от дублирования кода;
# - много красивых визуализаций в проекте и хорошая интерпретация;
# - при обучении моделей использована кросс-валидация и поиск гиперпараметров.
#
# Есть несколько моментов всего, на которые стоит ещё раз взглянуть, их я обзначил тебе в комментариях по ходу проекта. Предлагаю тебе доработать проект по моим комментариям, чтобы довести его до совершенства.
#
# Если будут вопросы, обращайся, с удовольствием на них отвечу.
# </div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
#
# <h2> Итоговый комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
#
#
# Теперь почти идеально. Принимаю работу)
#
# Если хочешь лучше разобраться в ML, то могу посоветовать тебе:
#
# - Открытый курс машинного обучения: https://habr.com/ru/company/ods/blog/322626/
#
# - Книжка от ШАД: https://academy.yandex.ru/handbook/ml/
#
# - Также рекомендую лекции от Andrew Ng: https://www.youtube.com/watch?v=PPLop4L2eGk&list=PLLssT5z_DsK-h9vYZkQkYNWcItqhlRJLN
# - Избежать утечки данных при кросс-валидации тебе поможет <a href="https://towardsdatascience.com/pipeline-columntransformer-and-featureunion-explained-f5491f815f">конвеерная обработка данных</a>.
#
# - Не все признаки приносят пользу при моделировании. Инструмент <a href="https://proglib.io/p/feature-selector">FeatureSelector</a> поможет тебе отобрать важные признаки и избавит от ручной обработки.  Также можешь посмотреть статью на <a href="https://www.kaggle.com/code/prashant111/comprehensive-guide-on-feature-selection/notebook">Kaggle</a> (она сложнее).
#
#
# В этом проекте были отработаны несколько моментов. А самый очевидный: заметно, что разность метрик качества (константной и нашей модели) -  не слишком большая. Такое расхождение метрик допустимо в этом проекте. Что тогда  для дальнейшего улучшения качества моделирования возможно тут пересмотреть?
# Попробую описать для тебя:
# 1. Качество данных на входе модели машинного обучения: повторно оценить аномалии, пропуски, соответствие законам химии и физики, все ли правдоподобно?
# 2. Работа с моделями машинного обучения:
# - Создание новых признаков для моделей, Features Engineering: возможно стоит обратиться к технологу производства и ещё раз пробежаться по бизнес-цепочке процесса.
# - Отбор самих моделей машинного обучения и гиперпараметров.
#
# 3. Параметры производственного процесса, к примеру: температура сырья, скорость ленточного конвейера, и.т.п.
#
#
# Если провести Анализ измерительных систем, или MSA, то можно разобраться в причинах неточности полученных с производства данных. Статистический анализ данных, или SPC, - тоже будет являться незаменимым помощником в решении нашей задачи.
#
# Добавлю здесь, что цель нашего проекта достигнута, а именно пройдены важные этапы подготовки данных и построения модели для производства золота.
#
# Успехов тебе в следующем спринте!
#
# Рад был помочь тебе)
#
# </div>

# %% [markdown]
# ## Чек-лист готовности проекта

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [ ]  Весь код выполняется без ошибок
# - [ ]  Ячейки с кодом расположены в порядке выполнения
# - [ ]  Выполнен шаг 1: данные подготовлены
#     - [ ]  Проверена формула вычисления эффективности обогащения
#     - [ ]  Проанализированы признаки, недоступные в тестовой выборке
#     - [ ]  Проведена предобработка данных
# - [ ]  Выполнен шаг 2: данные проанализированы
#     - [ ]  Исследовано изменение концентрации элементов на каждом этапе
#     - [ ]  Проанализированы распределения размеров гранул на обучающей и тестовой выборках
#     - [ ]  Исследованы суммарные концентрации
# - [ ]  Выполнен шаг 3: построена модель прогнозирования
#     - [ ]  Написана функция для вычисления итогового *sMAPE*
#     - [ ]  Обучено и проверено несколько моделей
#     - [ ]  Выбрана лучшая модель, её качество проверено на тестовой выборке
